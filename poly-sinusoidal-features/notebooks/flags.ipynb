# %%
from sklearn.preprocessing import (
    PolynomialFeatures,
    MinMaxScaler)
from sklearn.linear_model import (
    LinearRegression,
    Ridge,
    PoissonRegressor
    )
from sklearn.ensemble import (
    RandomForestRegressor
)
from sklearn.pipeline import Pipeline
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
full_source,ysource = fetch_openml(data_id=43927,return_X_y=True,as_frame=True)

full_source['Price'] = ysource

full_source['DATE']=pd.to_datetime(
    full_source['month'].astype(int).astype(str)+"/"+
    full_source['day'].astype(int).astype(str)+"/"+
    full_source['year'].astype(int).astype(str)
)

full_source.sort_values(by='DATE',ascending=True,inplace=True)
# Out:
# c:\Users\Jason\Desktop\git_control\ml-research\.venv\Lib\site-packages\sklearn\datasets\_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
mask = (full_source['region']=='WestTexNewMexico')&(full_source['type']=='organic')

# %%
source = full_source[mask].copy()

source.index = source['DATE'].values

# %%
source
# Out:
#             Total Volume     4046     4225  4770  Total Bags  Small Bags  \
# 2015-01-04       6182.81  1561.30  2958.17  0.00     1663.34     1663.34
# 2015-01-11       6861.73  1822.28  2377.54  0.00     2661.91     2656.66
# 2015-01-18       5508.20  1793.64  2078.72  0.00     1635.84     1620.00
# 2015-01-25       7324.06  1934.46  3032.72  0.00     2356.88     2320.00
# 2015-02-01       7210.19  1634.42  3012.44  0.00     2563.33     2563.33
# ...                  ...      ...      ...   ...         ...         ...
# 2018-02-25      18421.24  1974.26  2482.65  0.00    13964.33    13698.27
# 2018-03-04      17393.30  1832.24  1905.57  0.00    13655.49    13401.93
# 2018-03-11      22128.42  2162.67  3194.25  8.93    16762.57    16510.32
# 2018-03-18      15896.38  2055.35  1499.55  0.00    12341.48    12114.81
# 2018-03-25      15303.40  2325.30  2171.66  0.00    10806.44    10569.80
#
#             Large Bags  XLarge Bags     type    year            region  month  \
# 2015-01-04        0.00          0.0  organic  2015.0  WestTexNewMexico    1.0
# 2015-01-11        5.25          0.0  organic  2015.0  WestTexNewMexico    1.0
# 2015-01-18       15.84          0.0  organic  2015.0  WestTexNewMexico    1.0
# 2015-01-25       36.88          0.0  organic  2015.0  WestTexNewMexico    1.0
# 2015-02-01        0.00          0.0  organic  2015.0  WestTexNewMexico    2.0
# ...                ...          ...      ...     ...               ...    ...
# 2018-02-25      266.06          0.0  organic  2018.0  WestTexNewMexico    2.0
# 2018-03-04      253.56          0.0  organic  2018.0  WestTexNewMexico    3.0
# 2018-03-11      252.25          0.0  organic  2018.0  WestTexNewMexico    3.0
# 2018-03-18      226.67          0.0  organic  2018.0  WestTexNewMexico    3.0
# 2018-03-25      236.64          0.0  organic  2018.0  WestTexNewMexico    3.0
#
#              day  Price       DATE
# 2015-01-04   4.0   1.64 2015-01-04
# 2015-01-11  11.0   1.69 2015-01-11
# 2015-01-18  18.0   1.71 2015-01-18
# 2015-01-25  25.0   1.63 2015-01-25
# 2015-02-01   1.0   1.77 2015-02-01
# ...          ...    ...        ...
# 2018-02-25  25.0   1.57 2018-02-25
# 2018-03-04   4.0   1.54 2018-03-04
# 2018-03-11  11.0   1.56 2018-03-11
# 2018-03-18  18.0   1.56 2018-03-18
# 2018-03-25  25.0   1.62 2018-03-25
#
# [166 rows x 15 columns]

# %%
plt.plot(source['Total Volume'])

# %%
weeks = source['DATE'].dt.isocalendar().week
dates = source['DATE']

def sinu_feat(x,period=1,freq=53,func='sin'):

    if func=='sin':
        f = np.sin
    else:
        f = np.cos

    return f(2*np.pi*period*x/freq)

X = pd.DataFrame()
for f in ['sin','cos']:
    for p in [1]:
        X[f"SINU_{f.upper()}_{str(p)}"] = sinu_feat(weeks,period=p,freq=53,func=f)

X['PRICE'] = source['Price'].copy()
X['N'] = range(1,len(X)+1)

change_points_N = 1

change_points=dates[[int(len(dates)*(i/(change_points_N+1))) for i in range(1,change_points_N+1)]]

for d in change_points:
    X[f'change_point_{d}']=np.where(dates>=d,1,0)

# %%
X
# Out:
#             SINU_SIN_1  SINU_COS_1  PRICE    N  \
# 2015-01-04    0.118273    0.992981   1.64    1
# 2015-01-11    0.234886    0.972023   1.69    2
# 2015-01-18    0.348202     0.93742   1.71    3
# 2015-01-25    0.456629    0.889657   1.63    4
# 2015-02-01    0.558647    0.829406   1.77    5
# ...                ...         ...    ...  ...
# 2018-02-25    0.812487    0.582979   1.57  162
# 2018-03-04    0.875735    0.482792   1.54  163
# 2018-03-11     0.92669    0.375828   1.56  164
# 2018-03-18    0.964636    0.263587   1.56  165
# 2018-03-25     0.98904    0.147647   1.62  166
#
#             change_point_2016-08-14 00:00:00
# 2015-01-04                                 0
# 2015-01-11                                 0
# 2015-01-18                                 0
# 2015-01-25                                 0
# 2015-02-01                                 0
# ...                                      ...
# 2018-02-25                                 1
# 2018-03-04                                 1
# 2018-03-11                                 1
# 2018-03-18                                 1
# 2018-03-25                                 1
#
# [166 rows x 5 columns]

# %%
y = source['Total Volume'].copy()

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,
    test_size=.2,random_state=42,shuffle=False)

model = Pipeline(
    steps = [
        #('poly',PolynomialFeatures(degree=1,interaction_only=False)),
        ('scaler',MinMaxScaler()),
        ('learner',PoissonRegressor(alpha=0,max_iter=10000,tol=1e-12)),
        #('learner',RandomForestRegressor(n_estimators=25,min_samples_leaf=5,random_state=42))
    ]
).fit(Xtrain,ytrain)

yfit = pd.Series(model.predict(Xtrain),index = Xtrain.index)
ypred = pd.Series(model.predict(Xtest),index = Xtest.index)

plt.plot(y)
plt.plot(yfit)
plt.plot(ypred)
for d in change_points:
    plt.axvline(x=d, color='r', linestyle='--', label='Vertical Line')
plt.xticks(rotation=90)
plt.show()

# %%
subset = [i for i in X.columns if ('change_point_' not in i)]
Xtrain,Xtest,ytrain,ytest = train_test_split(X[subset],y,
    test_size=.2,random_state=42,shuffle=False)

model = Pipeline(
    steps = [
        #('poly',PolynomialFeatures(degree=1,interaction_only=False)),
        ('scaler',MinMaxScaler()),
        ('learner',PoissonRegressor(alpha=0,max_iter=10000,tol=1e-12)),
        #('learner',RandomForestRegressor(n_estimators=25,min_samples_leaf=5,random_state=42))
    ]
).fit(Xtrain,ytrain)

yfit = pd.Series(model.predict(Xtrain),index = Xtrain.index)
ypred = pd.Series(model.predict(Xtest),index = Xtest.index)

plt.plot(y)
plt.plot(yfit)
plt.plot(ypred)
for d in change_points:
    plt.axvline(x=d, color='r', linestyle='--', label='Vertical Line')
plt.xticks(rotation=90)
plt.show()
